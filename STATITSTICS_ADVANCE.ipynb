# %% [markdown]
# 1. What is a random variable in probability theory
# ANS. In probability theory, a random variable is a function that assigns a numerical value to each outcome in a sample space of a random experiment.
#
# 2. What are the types of random variables
# ANS. Types of Random Variables:
# Discrete Random Variable:
#
# Takes on a countable number of distinct values.
#
# Example: Number rolled on a fair six-sided die → values {1, 2, 3, 4, 5, 6}
#
# Continuous Random Variable:
#
# Takes on values in a continuous range (usually real numbers).
#
# Example: Time it takes for a bus to arrive → any non-negative real number.
#
# 3. What is the difference between discrete and continuous distributions
# ANS The main difference between discrete and continuous distributions lies in the types of values the random variables can take:
#
# Discrete Distributions:
# Deal with countable outcomes.
#
# The random variable can take specific, separate values, often integers.
#
# Examples: number of students in a class, number of heads in 10 coin tosses.
#
# Common distributions: Binomial, Poisson, Geometric.
#
# Example:
# Let
# 𝑋
# X be the number of defective bulbs in a box of 10.
# 𝑋
# X can be 0, 1, 2, ..., 10.
#
# Continuous Distributions:
# Deal with uncountable outcomes over an interval.
#
# The random variable can take any value within a range, including fractions and irrational numbers.
#
# Examples: height, weight, time, temperature.
#
# Common distributions: Normal (Gaussian), Exponential, Uniform (continuous).
#
# Example:
# Let
# 𝑌
# Y be the time (in seconds) it takes for a webpage to load.
# 𝑌
# Y can be any real number greater than 0.
#
# 4. What are probability distribution functions (PDF)
# ANS A Probability Distribution Function (PDF) is a function that describes the likelihood of a continuous random variable taking on a specific value or falling within a certain range. It's used in the context of continuous probability distributions.
#
# 5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)
# ANS A Cumulative Distribution Function (CDF) and a Probability Density Function (PDF) serve different purposes in describing a probability distribution, especially for continuous random variables. The PDF, denoted as
# 𝑓
# (
# 𝑥
# )
# f(x), represents the density of probability at a specific point, describing how likely a value is near
# 𝑥
# x, but not the exact probability of
# 𝑥
# x, which is always zero in the continuous case. In contrast, the CDF, denoted as
# 𝐹
# (
# 𝑥
# )
# F(x), gives the cumulative probability that the random variable is less than or equal to a particular value
# 𝑥
# x. Mathematically, the CDF is the integral of the PDF from negative infinity to
# 𝑥
# x, meaning it accumulates the total probability up to that point. While the PDF can take on values greater than one (since it is a density), the CDF always ranges from 0 to 1 and is a non-decreasing function. Essentially, the PDF shows the shape of the distribution, while the CDF tells you the proportion of observations that fall below a certain value.
#
# 6. What is a discrete uniform distribution
#  ANS  discrete uniform distribution is a type of probability distribution where all possible outcomes are equally likely. It applies to discrete random variables, meaning variables that take on a finite (or countably infinite) number of values
#
# 7. What are the key properties of a Bernoulli distribution?
# ANS The Bernoulli distribution is one of the simplest and most fundamental discrete probability distributions. It models the outcome of a single binary (yes/no or success/failure) experiment.
#
# 8. What is the binomial distribution, and how is it used in probability
# ans The binomial distribution is a discrete probability distribution that models the number of successes in a fixed number of independent trials, each with the same probability of success. It's used in situations where the outcome of each trial is binary (i.e., success or failure), and the trials are identical and independent.
#
# 9. What is the Poisson distribution and where is it applied
# ans The Poisson distribution is a discrete probability distribution that models the number of events occurring within a fixed interval of time or space, given that these events happen independently and at a constant average rate. It is commonly used to describe situations where events occur rarely but with a known average rate over a given period or area.
#
# 10. What is a continuous uniform distribution
# ans A continuous uniform distribution is a probability distribution where all outcomes are equally likely to occur within a given continuous range. In other words, every value in a specified interval has the same probability of being observed.
#
# 11. what are the characteristics of a normal distribution
# ans. The normal distribution, also known as the Gaussian distribution, is one of the most important and widely used probability distributions in statistics. It describes the distribution of many types of natural phenomena, such as height, weight, test scores, and measurement errors. The normal distribution is often referred to as the "bell curve" due to its symmetric, bell-shaped appearance.
#
# 12. What is the standard normal distribution, and why is it important
#
# ans The standard normal distribution is a special case of the normal distribution where the mean is 0 and the standard deviation is 1. It is a standardized version of the normal distribution, and it serves as a reference distribution for all normal distributions.
#
# 13. What is the Central Limit Theorem (CLT), and why is it critical in statistics
#
# ans The Central Limit Theorem (CLT) is one of the most important concepts in statistics, as it explains why the normal distribution is so commonly observed in practice, even when the underlying data isn't normally distributed. The CLT states that, for independent and identically distributed (i.i.d.) random variables with any distribution (whether normal or not), the sampling distribution of the sample mean will approach a normal distribution as the sample size increases, regardless of the shape of the original population distribution, provided the data has a finite mean and variance.
#
# 14. How does the Central Limit Theorem relate to the normal distribution
#
# ans. The Central Limit Theorem (CLT) directly relates to the normal distribution because it explains why the sampling distribution of the sample mean tends to follow a normal distribution, even if the underlying population distribution is not normal. Here’s a detailed breakdown of this relationship.
#
# 15. What is the application of Z statistics in hypothesis testing
#
# ans In hypothesis testing, z-statistics (or z-scores) are commonly used to assess whether a sample mean significantly differs from a population mean, especially when the population's standard deviation is known. Z-tests are a type of parametric test used to determine if there is enough statistical evidence to reject the null hypothesis.
#
# 16. How do you calculate a Z-score, and what does it represent
# ans A z-score (or standard score) is a statistical measure that describes a data point's position in terms of standard deviations relative to the mean of a data set. It indicates how many standard deviations a particular value (or observation) is above or below the mean of the distribution.
#
# Formula for Calculating a Z-Score:
# The formula to calculate the z-score for a given data point
# 𝑥
# x is:
#
# 𝑧
# =
# 𝑥
# −
# 𝜇
# 𝜎
# z=
# σ
# x−μ
# ​
#
# where:
#
# 𝑧
# z = z-score,
#
# 𝑥
# x = the raw score or data point you want to standardize,
#
# 𝜇
# μ = the population mean,
#
# 𝜎
# σ = the population standard deviation
#
# 17. What are point estimates and interval estimates in statistics
#
# ans In statistics, point estimates and interval estimates are both used to make inferences about a population parameter based on sample data. They are crucial concepts in statistical estimation, where the goal is to estimate unknown parameters (such as the population mean or proportion) based on observed data.
#
# 18. What is the significance of confidence intervals in statistical analysis
#
# ans. Confidence intervals (CIs) are a key concept in statistical analysis because they provide a range of plausible values for an unknown population parameter, such as the population mean, proportion, or difference between groups, based on sample data. They help quantify the uncertainty or reliability of an estimate, making them extremely important for drawing conclusions and making decisions based on sample data.
#
# 19. What is the relationship between a Z-score and a confidence interval
#
# ans The Z-score and confidence intervals are closely related concepts in statistics. A Z-score plays a key role in the construction of confidence intervals, particularly when dealing with large sample sizes or when the population standard deviation is known.
#
# 20. How are Z-scores used to compare different distributions
# ans Z-scores are incredibly useful when comparing different distributions because they allow you to standardize data from different distributions and make meaningful comparisons, even if the data comes from different scales or units. This is especially useful when comparing datasets with different means and standard deviations.
#
# 21. What are the assumptions for applying the Central Limit Theorem
#
# ans The Central Limit Theorem (CLT) is a foundational concept in statistics that allows us to make inferences about population parameters based on sample data. However, the CLT has certain assumptions that need to be met for it to apply correctly. These assumptions help ensure that the sampling distribution of the sample mean approximates a normal distribution, even when the population distribution is not normal.
#
# 22. What is the concept of expected value in a probability distribution
# ans The expected value (often referred to as the mean or average) is a fundamental concept in probability theory and statistics. It represents the long-run average or central tendency of a random variable in a probability distribution. In simple terms, the expected value is the weighted average of all possible outcomes, where each outcome is weighted by its probability of occurring.
#
# 23. How does a probability distribution relate to the expected outcome of a random variable
#
# ans A probability distribution describes the likelihood of different outcomes of a random variable. The expected value of a random variable is a key measure derived from the probability distribution that represents the long-term average or central tendency of the outcomes. In essence, the expected value is a weighted average of all possible values of the random variable, with each value weighted according to its probability of occurring.
